# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import requests

r = 'https://api-pub.bitfinex.com/v2/book/tBTCUSD/P2'

response = requests.get(r, params={'len': 100})
df = pd.DataFrame(response.json(), columns=['price', 'count', 'amount'])
df
# Out:
#      price  count      amount
# 0    19700    142  179.793230
# 1    19600     79  222.079684
# 2    19500    131   51.862341
# 3    19400    145   81.149545
# 4    19300    139   39.942591
# ..     ...    ...         ...
# 195  29300     17   -8.636327
# 196  29400     16   -0.064461
# 197  29500     18   -0.861903
# 198  29600     11   -0.055669
# 199  29700     13   -0.091328
#
# [200 rows x 3 columns]

# %%
df.dtypes
# Out:
# price       int64
# count       int64
# amount    float64
# dtype: object

# %%
bid = df[df['amount'] > 0]
ask = df[df['amount'] < 0]

# %%
sns.scatterplot(y=bid['price'], x=bid['amount'], size=bid['count'])
plt.show()

# %%
sns.scatterplot(y=ask['price'], x=ask['amount'], size=ask['count'])
plt.show()

# %% [markdown]
# ## P3

# %%
import requests

r = 'https://api-pub.bitfinex.com/v2/book/tBTCUSD/P3'

response = requests.get(r, params={'len': 100})
df = pd.DataFrame(response.json(), columns=['price', 'count', 'amount'])
bid = df[df['amount'] > 0]
ask = df[df['amount'] < 0]

# %%
sns.scatterplot(y=bid['price'], x=bid['amount'], size=bid['count'])
# Out:
# <AxesSubplot:xlabel='amount', ylabel='price'>

# %%
sns.scatterplot(y=ask['price'], x=ask['amount'], size=ask['count'])
# Out:
# <AxesSubplot:xlabel='amount', ylabel='price'>
